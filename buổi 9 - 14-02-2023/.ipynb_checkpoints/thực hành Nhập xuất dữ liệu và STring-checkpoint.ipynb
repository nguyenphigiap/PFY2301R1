# %% [markdown]
# ![image.png](attachment:image.png)

# %%
so_nguyen = int(input("nhập vào số nguyên n: "))
binh_phuong_n = so_nguyen * so_nguyen
print(f"bình phương là: {binh_phuong_n}")
# Out:
# nhập vào số nguyên n: 4
# bình phương là: 16

# %%
# chữa bài
n = int(input("Please input number:"))
result = n * n
print(f"Square number of {n} is {result}")
# Out:
# Please input number:4
# Square number of 4 is 16

# %% [markdown]
# # bài tiếp theo
# title = "No.,Fullname,Math,Physics,Chemistry"
# data = "1,Nguyen Van A,8.0,9.5,7.4"
#
# # trích xuất ra các điểm số Toán , Lý, Hóa và tính ra
# # điểm trung bình của học sinh Nguyen Van A
# # kết quả in ra làm tròn 1 chữ số thập phân

# %%
title = "No.,Fullname,Math,Physics,Chemistry"
data = "1,Nguyen Van A,8.0,9.5,7.4"
# trích xuất điểm
print(f"Điểm toán là: {data[15:18]}")
print(f"Điểm lý là: {data[19:22]}")
print(f"Điểm hóa là: {data[23:]}")

Math = data[15:18]
Physics = data[19:22]
Chemistry = data[23:]
# Out:
# Điểm toán là: 8.0
# Điểm lý là: 9.5
# Điểm hóa là: 7.4
# 8.0

# %% [markdown]
# # chữa bài

# %%
Math_score = float(data[15:18])
Physice_score = float(data[19:22])
chemistry_score = float(data[15:18])

average_score = round((Math_score + Physice_score + chemistry_score) / 3, 1)

print(f"Math_score is {Math_score}")
print(f"Physice_score is {Physice_score}")
print(f"chemistry_score is {chemistry_score}")
print(f"Average score is {average_score}")
# Out:
# Math_score is 8.0
# Physice_score is 9.5
# chemistry_score is 8.0
# Average score is 8.5
